# %%
import numpy as np
import matplotlib.pyplot as plt
from UPVfab_tools import open_file, filter_wavelength, smooth_signal

# %%
wl_0 = 1530
wl_1 = 1610

# %%
file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/10/B1\source.txt"
wavelength_p0_r1, power_p0_r1 = open_file(file_path)
wavelength_p0_r1, power_p0_r1 = filter_wavelength(wavelength_p0_r1, power_p0_r1, wl_0, wl_1)

# file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/10/B1\wg1_49_degrees.txt"
# wavelength_p1_r1, power_p1_r1 = open_file(file_path)
# wavelength_p1_r1, power_p1_r1 = filter_wavelength(wavelength_p1_r1, power_p1_r1, wl_0, wl_1)

file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/10/B1\wg1_48_degrees.txt"
wavelength_p2_r1, power_p2_r1 = open_file(file_path)
wavelength_p2_r1, power_p2_r1 = filter_wavelength(wavelength_p2_r1, power_p2_r1, wl_0, wl_1)

file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/10/B1\wg1_46_degrees.txt"
wavelength_p3_r1, power_p3_r1 = open_file(file_path)
wavelength_p3_r1, power_p3_r1 = filter_wavelength(wavelength_p3_r1, power_p3_r1, wl_0, wl_1)

file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/10/B1\wg1_44_degrees.txt"
wavelength_p4_r1, power_p4_r1 = open_file(file_path)
wavelength_p4_r1, power_p4_r1 = filter_wavelength(wavelength_p4_r1, power_p4_r1, wl_0, wl_1)

file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/10/B1\wg1_45_degrees.txt"
wavelength_p5_r1, power_p5_r1 = open_file(file_path)
wavelength_p5_r1, power_p5_r1 = filter_wavelength(wavelength_p5_r1, power_p5_r1, wl_0, wl_1)

file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/10/B1\wg1_47_degrees.txt"
wavelength_p6_r1, power_p6_r1 = open_file(file_path)
wavelength_p6_r1, power_p6_r1 = filter_wavelength(wavelength_p6_r1, power_p6_r1, wl_0, wl_1)

plt.figure(figsize = (10, 5))
plt.plot(wavelength_p0_r1, power_p0_r1, label = 'Fuente')
#plt.plot(wavelength_p1_r1, power_p1_r1, label = '49º')
plt.plot(wavelength_p2_r1, power_p2_r1, label = '48º')
plt.plot(wavelength_p6_r1, power_p6_r1, label = '47º')
plt.plot(wavelength_p3_r1, power_p3_r1, label = '46º')
plt.plot(wavelength_p5_r1, power_p5_r1, label = '45º')
plt.plot(wavelength_p4_r1, power_p4_r1, label = '44º')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Power (dBm)')
plt.title('Measurements')
plt.legend()
plt.grid()
plt.show()

#plt.plot(wavelength_p0_r1, power_p1_r1 - power_p0_r1, label = '49º')
plt.plot(wavelength_p0_r1, power_p2_r1 - power_p0_r1, label = '48')
plt.plot(wavelength_p0_r1, power_p6_r1 - power_p0_r1, label = '47')
plt.plot(wavelength_p0_r1, power_p3_r1 - power_p0_r1, label = '46')
plt.plot(wavelength_p0_r1, power_p5_r1 - power_p0_r1, label = '45')
plt.plot(wavelength_p0_r1, power_p4_r1 - power_p0_r1, label = '44')
plt.xlabel(r'$\lambda$ [nm]', fontsize=12)
plt.ylabel('Normalized Power [dBm]', fontsize=12)
#plt.title('Measurements (Normalized)')
plt.legend(title='Angle [º]')
plt.grid(which='both', alpha=0.5)
plt.savefig("GC_spectra.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
angle = [44, 45, 46, 47, 48]
power = []
wavelength_p0_r1, power_p0_r1 = filter_wavelength(wavelength_p0_r1, power_p0_r1, 1549.9, 1550.1)
power_0 = np.mean(power_p0_r1)

wavelength_p4_r1, power_p4_r1 = filter_wavelength(wavelength_p4_r1, power_p4_r1, 1549.9, 1550.1)
power.append(np.mean(power_p4_r1) - power_0)

wavelength_p5_r1, power_p5_r1 = filter_wavelength(wavelength_p5_r1, power_p5_r1, 1549.9, 1550.1)
power.append(np.mean(power_p5_r1) - power_0)

wavelength_p3_r1, power_p3_r1 = filter_wavelength(wavelength_p3_r1, power_p3_r1, 1549.9, 1550.1)
power.append(np.mean(power_p3_r1) - power_0)

wavelength_p6_r1, power_p6_r1 = filter_wavelength(wavelength_p6_r1, power_p6_r1, 1549.9, 1550.1)
power.append(np.mean(power_p6_r1) - power_0)

wavelength_p2_r1, power_p2_r1 = filter_wavelength(wavelength_p2_r1, power_p2_r1, 1549.9, 1550.1)
power.append(np.mean(power_p2_r1) - power_0)

plt.figure(figsize=(4, 5))
plt.plot(angle, power, color='b')
#plt.title('Normalized power (1550 nm)')
plt.xlabel('Angle [º]')
plt.ylabel('Normalized Power [dBm]')
plt.grid()
#plt.savefig("GC_angle.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
# Fabricación
# Oxidación del Si para crear capa SiO2
# Deposito de capa homogenea de nitruro
# Deposito de fotoresina positiva
# Quitar nitruro no expuesto (lift-up)
# Stripping (quitar fotoeresina)
# PECVD de SiO2 o Depositar BCB (han salido unos 400 nm por encima de las guías)

# Motivación: Modelar IBGs y maduración tecnología UPVfab como paso previo a los diseños
# Teoría: Diseño de redes de Bragg
# Simulaciones
# Diseño y fabricación
# Caracterización y resultados

# %%
file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/10/A6\laser.txt"
wavelength_laser, power_laser = open_file(file_path)
wavelength_laser, power_laser = filter_wavelength(wavelength_laser, power_laser, wl_0, wl_1)

file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/10/A6\wg1.txt"
wavelength_wg1, power_wg1 = open_file(file_path)
wavelength_wg1, power_wg1 = filter_wavelength(wavelength_wg1, power_wg1, wl_0, wl_1)

file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/10/A6\wg2.txt"
wavelength_wg2, power_wg2 = open_file(file_path)
wavelength_wg2, power_wg2 = filter_wavelength(wavelength_wg2, power_wg2, wl_0, wl_1)

file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/10/A6\spiral1.txt"
wavelength_spiral1, power_spiral1 = open_file(file_path)
wavelength_spiral1, power_spiral1 = filter_wavelength(wavelength_spiral1, power_spiral1, wl_0, wl_1)

file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/10/A6\spiral2.txt"
wavelength_spiral2, power_spiral2 = open_file(file_path)
wavelength_spiral2, power_spiral2 = filter_wavelength(wavelength_spiral2, power_spiral2, wl_0, wl_1)

#plt.plot(wavelength_laser, power_laser, label = 'Fuente')
plt.plot(wavelength_wg1, power_wg1, label = 'REF 1')
plt.plot(wavelength_wg2, power_wg2, label = 'REF 2')
plt.plot(wavelength_spiral1, power_spiral1, label = 'REF S1')
plt.plot(wavelength_spiral2, power_spiral2, label = 'REF S2')
plt.xlabel(r'$\lambda$ [nm]', fontsize=12)
plt.ylabel('Power [dBm]', fontsize=12)
#plt.title('R10 Reference WGs')
plt.legend(fontsize=11)
plt.grid(which='both', alpha=0.5)
plt.savefig("R10_reference.png", dpi=300, bbox_inches="tight")
plt.show()

plt.plot(wavelength_wg1, power_wg1 - power_laser, label = 'REF 1')
plt.plot(wavelength_wg2, power_wg2 - power_laser, label = 'REF 2')
plt.plot(wavelength_spiral1, power_spiral1 - power_laser, label = 'REF S1')
plt.plot(wavelength_spiral2, power_spiral2 - power_laser, label = 'REF S2')
plt.xlabel('Wavelength (nm)', fontsize=12)
plt.ylabel('Power (dBm)', fontsize=12)
plt.title('R10 Reference WGs (Normalized)')
plt.legend()
plt.grid()
plt.show()

file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/10/A6\U1_1550.txt"
wavelength_U1_1550, power_U1_1550 = open_file(file_path)
wavelength_U1_1550, power_U1_1550 = filter_wavelength(wavelength_U1_1550, power_U1_1550, wl_0, wl_1)

file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/10/A6\U2_1550.txt"
wavelength_U2_1550, power_U2_1550 = open_file(file_path)
wavelength_U2_1550, power_U2_1550 = filter_wavelength(wavelength_U2_1550, power_U2_1550, wl_0, wl_1)

file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/10/A6\U3_1550.txt"
wavelength_U3_1550, power_U3_1550 = open_file(file_path)
wavelength_U3_1550, power_U3_1550 = filter_wavelength(wavelength_U3_1550, power_U3_1550, wl_0, wl_1)

file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/10/A6\U1s_1550.txt"
wavelength_U1s_1550, power_U1s_1550 = open_file(file_path)
wavelength_U1s_1550, power_U1s_1550 = filter_wavelength(wavelength_U1s_1550, power_U1s_1550, wl_0, wl_1)

file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/10/A6\U2s_1550.txt"
wavelength_U2s_1550, power_U2s_1550 = open_file(file_path)
wavelength_U2s_1550, power_U2s_1550 = filter_wavelength(wavelength_U2s_1550, power_U2s_1550, wl_0, wl_1)

file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/10/A6\U3s_1550.txt"
wavelength_U3s_1550, power_U3s_1550 = open_file(file_path)
wavelength_U3s_1550, power_U3s_1550 = filter_wavelength(wavelength_U3s_1550, power_U3s_1550, wl_0, wl_1)

power_wg_mean = (power_wg1 + power_wg2)/2
power_spiral_mean = (power_spiral1 + power_spiral2)/2

plt.plot(wavelength_U1_1550, power_U1_1550, label = 'U1')
plt.plot(wavelength_U2_1550, power_U2_1550, label = 'U2')
plt.plot(wavelength_U3_1550, power_U3_1550, label = 'U3')
plt.plot(wavelength_U1s_1550, power_U1s_1550, label = 'U1s')
plt.plot(wavelength_U2s_1550, power_U2s_1550, label = 'U2s')
plt.plot(wavelength_U3s_1550, power_U3s_1550, label = 'U3s')
plt.xlabel(r'$\lambda$ [nm]', fontsize=12)
plt.ylabel('Power [dBm]', fontsize=12)
#plt.title('R10 Gratings')
plt.legend(fontsize=11, loc='lower left', ncol=2)
plt.grid(which='both', alpha=0.5)
plt.savefig("R10_gratings.png", dpi=300, bbox_inches="tight")
plt.show()

plt.plot(wavelength_U1_1550, power_U1_1550 - power_wg_mean, label = 'U1')
plt.plot(wavelength_U2_1550, power_U2_1550 - power_wg_mean, label = 'U2')
plt.plot(wavelength_U3_1550, power_U3_1550 - power_wg_mean, label = 'U3')
plt.plot(wavelength_U1s_1550, power_U1s_1550 - power_spiral_mean, label = 'U1s')
plt.plot(wavelength_U2s_1550, power_U2s_1550 - power_spiral_mean, label = 'U2s')
plt.plot(wavelength_U3s_1550, power_U3s_1550 - power_spiral_mean, label = 'U3s')
plt.xlabel('Wavelength (nm)', fontsize=12)
plt.ylabel('Power (dBm)', fontsize=12)
plt.title('R10 Gratings (Normalized)', fontsize=12)
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize = (10, 5))
plt.plot(wavelength_wg1, power_wg1 - power_laser, label = 'REF 1')
plt.plot(wavelength_wg2, power_wg2 - power_laser, label = 'REF 2')
# plt.plot(wavelength_spiral1, power_spiral1 - power_laser, label = 'REF S1')
# plt.plot(wavelength_spiral1, power_spiral2 - power_laser, label = 'REF S2')
plt.plot(wavelength_U1_1550, power_U1_1550 - power_laser, label = 'U1')
plt.plot(wavelength_U2_1550, power_U2_1550 - power_laser, label = 'U2')
plt.plot(wavelength_U3_1550, power_U3_1550 - power_laser, label = 'U3')
# plt.plot(wavelength_U1s_1550, power_U1s_1550 - power_laser, label = 'U1s')
# plt.plot(wavelength_U2s_1550, power_U2s_1550 - power_laser, label = 'U2s')
# plt.plot(wavelength_U3s_1550, power_U3s_1550 - power_laser, label = 'U3s')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Power (dBm)')
plt.title('R10 Grating Couplers')
plt.legend()
plt.grid()
plt.show()

# %%
file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/10/A6\U1_1560.txt"
wavelength_U1_1560, power_U1_1560 = open_file(file_path)
wavelength_U1_1560, power_U1_1560 = filter_wavelength(wavelength_U1_1560, power_U1_1560, wl_0, wl_1)

file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/10/A6\U2_1560.txt"
wavelength_U2_1560, power_U2_1560 = open_file(file_path)
wavelength_U2_1560, power_U2_1560 = filter_wavelength(wavelength_U2_1560, power_U2_1560, wl_0, wl_1)

file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/10/A6\U3_1560.txt"
wavelength_U3_1560, power_U3_1560 = open_file(file_path)
wavelength_U3_1560, power_U3_1560 = filter_wavelength(wavelength_U3_1560, power_U3_1560, wl_0, wl_1)

plt.figure(figsize = (10, 5))
plt.plot(wavelength_U1_1560, power_U1_1560, label = 'U1')
plt.plot(wavelength_U2_1560, power_U2_1560, label = 'U2')
plt.plot(wavelength_U3_1560, power_U3_1560, label = 'U3')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Power (dBm)')
plt.title('R10 Gratings')
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize = (10, 5))
plt.plot(wavelength_U1_1560, power_U1_1560 - power_wg_mean, label = 'U1')
plt.plot(wavelength_U2_1560, power_U2_1560 - power_wg_mean, label = 'U2')
plt.plot(wavelength_U3_1560, power_U3_1560 - power_wg_mean, label = 'U3')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Power (dBm)')
plt.title('R10 Gratings (Normalized)')
plt.legend()
plt.grid()
plt.show()

# %%
file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/4/A6\wg1.txt"
wavelength_wg1, power_wg1 = open_file(file_path)
wavelength_wg1, power_wg1 = filter_wavelength(wavelength_wg1, power_wg1, wl_0, wl_1)

file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/4/A6\wg2.txt"
wavelength_wg2, power_wg2 = open_file(file_path)
wavelength_wg2, power_wg2 = filter_wavelength(wavelength_wg2, power_wg2, wl_0, wl_1)

file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/4/A6\spiral1.txt"
wavelength_spiral1, power_spiral1 = open_file(file_path)
wavelength_spiral1, power_spiral1 = filter_wavelength(wavelength_spiral1, power_spiral1, wl_0, wl_1)

file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/4/A6\spiral2.txt"
wavelength_spiral2, power_spiral2 = open_file(file_path)
wavelength_spiral2, power_spiral2 = filter_wavelength(wavelength_spiral2, power_spiral2, wl_0, wl_1)

power_wg_mean = (power_wg1 + power_wg2)/2
power_spiral_mean = (power_spiral1 + power_spiral2)/2

plt.plot(wavelength_laser, power_laser, label = 'Fuente')
plt.plot(wavelength_wg1, power_wg1, label = 'REF 1')
plt.plot(wavelength_wg2, power_wg2, label = 'REF 2')
plt.plot(wavelength_spiral1, power_spiral1, label = 'REF S1')
plt.plot(wavelength_spiral2, power_spiral2, label = 'REF S2')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Power (dBm)')
plt.title('R4 Reference WGs')
plt.legend()
plt.grid()
plt.show()

plt.plot(wavelength_wg1, power_wg1 - power_laser, label = 'REF 1')
plt.plot(wavelength_wg2, power_wg2 - power_laser, label = 'REF 2')
plt.plot(wavelength_spiral1, power_spiral1 - power_laser, label = 'REF S1')
plt.plot(wavelength_spiral1, power_spiral2 - power_laser, label = 'REF S2')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Power (dBm)')
plt.title('R4 Reference WGs (Normalized)')
plt.legend()
plt.grid()
plt.show()

file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/4/A6\U1_1550.txt"
wavelength_U1_1550, power_U1_1550 = open_file(file_path)
wavelength_U1_1550, power_U1_1550 = filter_wavelength(wavelength_U1_1550, power_U1_1550, wl_0, wl_1)

file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/4/A6\U2_1550.txt"
wavelength_U2_1550, power_U2_1550 = open_file(file_path)
wavelength_U2_1550, power_U2_1550 = filter_wavelength(wavelength_U2_1550, power_U2_1550, wl_0, wl_1)

file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/4/A6\U3_1550.txt"
wavelength_U3_1550, power_U3_1550 = open_file(file_path)
wavelength_U3_1550, power_U3_1550 = filter_wavelength(wavelength_U3_1550, power_U3_1550, wl_0, wl_1)

plt.plot(wavelength_U1_1550, power_U1_1550, label = 'U1')
plt.plot(wavelength_U2_1550, power_U2_1550, label = 'U2')
plt.plot(wavelength_U3_1550, power_U3_1550, label = 'U3')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Power (dBm)')
plt.title('R4 Gratings')
plt.legend()
plt.grid()
plt.show()

plt.plot(wavelength_U1_1550, power_U1_1550 - power_wg_mean, label = 'U1')
plt.plot(wavelength_U2_1550, power_U2_1550 - power_wg_mean, label = 'U2')
plt.plot(wavelength_U3_1550, power_U3_1550 - power_wg_mean, label = 'U3')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Power (dBm)')
plt.title('R4 Gratings (Normalized)')
plt.legend()
plt.grid()
plt.show()

# %%
file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1471/3/A6\laser.txt"
wavelength_laser, power_laser = open_file(file_path)
wavelength_laser, power_laser = filter_wavelength(wavelength_laser, power_laser, wl_0, wl_1)

file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1471/3/A6\wg1.txt"
wavelength_wg1, power_wg1 = open_file(file_path)
wavelength_wg1, power_wg1 = filter_wavelength(wavelength_wg1, power_wg1, wl_0, wl_1)

file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1471/3/A6\wg2.txt"
wavelength_wg2, power_wg2 = open_file(file_path)
wavelength_wg2, power_wg2 = filter_wavelength(wavelength_wg2, power_wg2, wl_0, wl_1)

# file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/10/A6\spiral1.txt"
# wavelength_spiral1, power_spiral1 = open_file(file_path)
# wavelength_spiral1, power_spiral1 = filter_wavelength(wavelength_spiral1, power_spiral1, wl_0, wl_1)

# file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/10/A6\spiral2.txt"
# wavelength_spiral2, power_spiral2 = open_file(file_path)
# wavelength_spiral2, power_spiral2 = filter_wavelength(wavelength_spiral2, power_spiral2, wl_0, wl_1)

plt.figure(figsize = (10, 5))
plt.plot(wavelength_laser, power_laser, label = 'Fuente')
plt.plot(wavelength_wg1, power_wg1, label = 'REF 1')
plt.plot(wavelength_wg2, power_wg2, label = 'REF 2')
# plt.plot(wavelength_spiral1, power_spiral1, label = 'REF S1')
# plt.plot(wavelength_spiral2, power_spiral2, label = 'REF S2')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Power (dBm)')
plt.title('R3 Reference WGs')
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize = (10, 5))
plt.plot(wavelength_wg1, power_wg1 - power_laser, label = 'REF 1')
plt.plot(wavelength_wg2, power_wg2 - power_laser, label = 'REF 2')
# plt.plot(wavelength_spiral1, power_spiral1 - power_laser, label = 'REF S1')
# plt.plot(wavelength_spiral1, power_spiral2 - power_laser, label = 'REF S2')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Power (dBm)')
plt.title('R3 Reference WGs (Normalized)')
plt.legend()
plt.grid()
plt.show()

file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1471/3/A6\U1_1550.txt"
wavelength_U1_1550, power_U1_1550 = open_file(file_path)
wavelength_U1_1550, power_U1_1550 = filter_wavelength(wavelength_U1_1550, power_U1_1550, wl_0, wl_1)

file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1471/3/A6\U2_1550.txt"
wavelength_U2_1550, power_U2_1550 = open_file(file_path)
wavelength_U2_1550, power_U2_1550 = filter_wavelength(wavelength_U2_1550, power_U2_1550, wl_0, wl_1)

file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1471/3/A6\U3_1550.txt"
wavelength_U3_1550, power_U3_1550 = open_file(file_path)
wavelength_U3_1550, power_U3_1550 = filter_wavelength(wavelength_U3_1550, power_U3_1550, wl_0, wl_1)

# file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/10/A6\U1s_1550.txt"
# wavelength_U1s_1550, power_U1s_1550 = open_file(file_path)
# wavelength_U1s_1550, power_U1s_1550 = filter_wavelength(wavelength_U1s_1550, power_U1s_1550, wl_0, wl_1)

# file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/10/A6\U2s_1550.txt"
# wavelength_U2s_1550, power_U2s_1550 = open_file(file_path)
# wavelength_U2s_1550, power_U2s_1550 = filter_wavelength(wavelength_U2s_1550, power_U2s_1550, wl_0, wl_1)

# file_path= r"/home/arjoa/UPVfab/test_osa/data/MPWrun0/V053_1470/10/A6\U3s_1550.txt"
# wavelength_U3s_1550, power_U3s_1550 = open_file(file_path)
# wavelength_U3s_1550, power_U3s_1550 = filter_wavelength(wavelength_U3s_1550, power_U3s_1550, wl_0, wl_1)

power_wg_mean = (power_wg1 + power_wg2)/2
power_spiral_mean = (power_spiral1 + power_spiral2)/2

plt.figure(figsize = (10, 5))
plt.plot(wavelength_U1_1550, power_U1_1550, label = 'U1')
plt.plot(wavelength_U2_1550, power_U2_1550, label = 'U2')
plt.plot(wavelength_U3_1550, power_U3_1550, label = 'U3')
# plt.plot(wavelength_U1s_1550, power_U1s_1550, label = 'U1s')
# plt.plot(wavelength_U2s_1550, power_U2s_1550, label = 'U2s')
# plt.plot(wavelength_U3s_1550, power_U3s_1550, label = 'U3s')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Power (dBm)')
plt.title('R3 Gratings')
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize = (10, 5))
plt.plot(wavelength_U1_1550, power_U1_1550 - power_wg_mean, label = 'U1')
plt.plot(wavelength_U2_1550, power_U2_1550 - power_wg_mean, label = 'U2')
plt.plot(wavelength_U3_1550, power_U3_1550 - power_wg_mean, label = 'U3')
# plt.plot(wavelength_U1s_1550, power_U1s_1550 - power_spiral_mean, label = 'U1s')
# plt.plot(wavelength_U2s_1550, power_U2s_1550 - power_spiral_mean, label = 'U2s')
# plt.plot(wavelength_U3s_1550, power_U3s_1550 - power_spiral_mean, label = 'U3s')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Power (dBm)')
plt.title('R3 Gratings (Normalized)')
plt.legend()
plt.grid()
plt.show()
